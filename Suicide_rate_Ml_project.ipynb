# %% [markdown]
# <a href="https://colab.research.google.com/github/SKB2003/SKB2003/blob/main/Suicide_rate_Ml_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Sucide3.csv')

# %%
datadata.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_per_capita ($)  \
# 0               6.71  Albania1987           NaN                 796
# 1               5.19  Albania1987           NaN                 796
# 2               4.83  Albania1987           NaN                 796
# 3               4.59  Albania1987           NaN                 796
# 4               3.28  Albania1987           NaN                 796
#
#         generation
# 0     Generation X
# 1           Silent
# 2     Generation X
# 3  G.I. Generation
# 4          Boomers

# %% [markdown]
# DATA EXPLORATION

# %%
# Display the first few rows of the dataset
print(data.head())
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_per_capita ($)  \
# 0               6.71  Albania1987           NaN                 796
# 1               5.19  Albania1987           NaN                 796
# 2               4.83  Albania1987           NaN                 796
# 3               4.59  Albania1987           NaN                 796
# 4               3.28  Albania1987           NaN                 796
#
#         generation
# 0     Generation X
# 1           Silent
# 2     Generation X
# 3  G.I. Generation
# 4          Boomers

# %%
# Check the column names and data types
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9   gdp_per_capita ($)  27820 non-null  int64
#  10  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 2.3+ MB
# None

# %%
# Check the summary statistics of numerical columns
print(data.describe())
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# ...

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
# Drop the "HDI for year" column
data.drop("HDI for year", axis=1, inplace=True)

# %%
print(data.head())
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  gdp_per_capita ($)       generation
# 0               6.71  Albania1987                 796     Generation X
# 1               5.19  Albania1987                 796           Silent
# 2               4.83  Albania1987                 796     Generation X
# 3               4.59  Albania1987                 796  G.I. Generation
# 4               3.28  Albania1987                 796          Boomers

# %%
data.dtypes
# Out:
# country                object
# year                    int64
# sex                    object
# age                    object
# suicides_no             int64
# population              int64
# suicides/100k pop     float64
# country-year           object
# gdp_per_capita ($)      int64
# generation             object
# dtype: object

# %%
data['age'] = data['age'].astype(str)

# %%
data['age'] = data['age'].str.replace(' years', '')

# %%
data.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'gdp_per_capita ($)',
#        'generation'],
#       dtype='object')

# %% [markdown]
# **DATA VISUALIZATION**

# %%
# Data visualization

# Histogram of suicides_no column
plt.hist(data['suicides_no'])
plt.xlabel('Number of Suicides')
plt.ylabel('Frequency')
plt.title('Distribution of Suicides')
plt.show()

# Scatter plot of suicides_no versus gdp_per_capita
plt.scatter(data['gdp_per_capita ($)'], data['suicides_no'])
plt.xlabel('GDP per Capita')
plt.ylabel('Number of Suicides')
plt.title('Suicides vs. GDP per Capita')
plt.show()

# Bar plot of suicides by generation
sns.countplot(x='generation', data=data)
plt.xlabel('Generation')
plt.ylabel('Number of Suicides')
plt.title('Suicides by Generation')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **REGRESSION MODELS**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score

# Instantiate the regression models
tree_model = DecisionTreeRegressor()
forest_model = RandomForestRegressor()
gbr_model = GradientBoostingRegressor()
xgbr_model = xgb.XGBRegressor()
adaboost_model = AdaBoostRegressor()

# Define a list of models
models = [tree_model, forest_model, gbr_model, xgbr_model, adaboost_model]

# Iterate over the models and calculate MSE and R-squared
for model in models:
    # Fit the model to the training data
    model.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = model.predict(X_test)

    # Calculate the mean squared error
    mse = mean_squared_error(y_test, y_pred)

    # Calculate the R-squared score
    r2 = r2_score(y_test, y_pred)

    # Print the model name, MSE, and R-squared score
    print(f"{model.__class__.__name__} - MSE: {mse:.2f}, R-squared: {r2:.4f}")
# Out:
# DecisionTreeRegressor - MSE: 3844.13, R-squared: 0.9949
# RandomForestRegressor - MSE: 5950.52, R-squared: 0.9921
# GradientBoostingRegressor - MSE: 6856.14, R-squared: 0.9909
# XGBRegressor - MSE: 2410.41, R-squared: 0.9968
# AdaBoostRegressor - MSE: 131163.31, R-squared: 0.8266

# %% [markdown]
# GRAPH PLOTTING FOR DIFFERENT MODELS

# %%
import matplotlib.pyplot as plt

# Create a figure and axis
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

# Define a list of models
models = [tree_model, forest_model, gbr_model, xgbr_model, adaboost_model]

# Iterate over the models and plot the predicted vs actual values
for i, model in enumerate(models):
    # Fit the model to the training data
    model.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = model.predict(X_test)

    # Plot the predicted vs actual values
    row = i // 3
    col = i % 3
    axs[row, col].scatter(y_test, y_pred)
    axs[row, col].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
    axs[row, col].set_xlabel('Actual')
    axs[row, col].set_ylabel('Predicted')
    axs[row, col].set_title(model.__class__.__name__)

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
